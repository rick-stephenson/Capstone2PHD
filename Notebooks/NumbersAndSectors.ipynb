# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Excel files downloaded from:
# https://ncsesdata.nsf.gov/doctoratework/2017/
#
# "Survey of Doctorate Recipients Survey Year 2017"
# From above web site: "The Survey of Doctorate Recipients (SDR) provides demographic, education, and career history information from individuals with a U.S. research doctoral degree in a science, engineering, or health (SEH) field. The SDR is sponsored by the National Center for Science and Engineering Statistics and by the National Institutes of Health. Conducted since 1973, the SDR is a unique source of information about the educational and occupational achievements and career movement of U.S.-trained doctoral scientists and engineers in the United States and abroad."

# %% [markdown]
# Third sheet to import is Table 54. Median annual salaries of U.S. residing full-time employed doctoral scientists and engineers, by field of doctorate and sector of employment: 2017
#
# Footnotes from Table 54:
# Codes used in data tables: * = suppressed when population estimate < 25. D = suppressed to avoid disclosure of confidential information. na = not applicable. S = suppressed for reliability; coefficient of variation exceeds publication standards.
# SE = standard error.
# a Includes 4-year colleges or universities, medical schools (including university-affiliated hospitals or medical centers), and university-affiliated research institutes.
# b Includes 2-year colleges, community colleges, or technical institutes, and other precollege institutions.
# c Includes those self-employed in an incorporated business.
# d Self-employed or business owner in a nonincorporated business.
# e Includes employers not broken out separately.
# NOTES: Median annual salaries are for principal job and are rounded to nearest $1,000. Standard errors are rounded up to the nearest $500. Residence location is based on reported living location on 1 February 2017.
# SOURCE:  National Science Foundation, National Center for Science and Engineering Statistics, Survey of Doctorate Recipients: 2017.

# %%
sectorDF = pd.read_excel(r'..\data\raw\sdr2017_dst_54.xlsx', skiprows = 3)
sectorDF.head()
# Out:
#                                       Field of study All full-time employed  \
# 0                                                NaN          Median salary
# 1                                         All fields                 110000
# 2                                            Science                 104000
# 3  Biological, agricultural, and environmental li...                 100000
# 4                     Agricultural and food sciences                 106000
#
#   Unnamed: 2 4-year educational institutiona Unnamed: 4  \
# 0         SE                   Median salary         SE
# 1        500                           90000        500
# 2       1000                           88000       1000
# 3        500                           84000       1500
# 4       3000                           94000       3000
#
#   Other educational institutionb Unnamed: 6 Private, for profitc Unnamed: 8  \
# 0                  Median salary         SE        Median salary         SE
# 1                          71000       1000               137000       2000
# 2                          71000       1000               135000       1000
# 3                          69000       1000               130000       1000
# 4                          88000      20000               125000       2500
#
#   Private, nonprofit Unnamed: 10 Federal government Unnamed: 12  \
# 0      Median salary          SE      Median salary          SE
# 1             114000        2000             120000         500
# 2             109000         500             118000        2000
# 3             105000        4000             110000        3000
# 4             100000        9500             115000        3000
#
#   State or local government Unnamed: 14 Self-employedd Unnamed: 16  \
# 0             Median salary          SE  Median salary          SE
# 1                     90000        1000          99000         500
# 2                     86000        3000         100000        2000
# 3                     79000        2500          99000        9500
# 4                     79000       11000          89000       16500
#
#           Othere Unnamed: 18
# 0  Median salary          SE
# 1         124000        4500
# 2         124000        4500
# 3          89000        8000
# 4          65000       18000

# %%
sectorDF.tail(12)
# Out:
#                                        Field of study All full-time employed  \
# 31                                  Other engineering                 123000
# 32                                             Health                 104000
# 33                                                NaN                    NaN
# 34  Codes used in data tables: * = suppressed when...                    NaN
# 35                               SE = standard error.                    NaN
# 36  a Includes 4-year colleges or universities, me...                    NaN
# 37  b Includes 2-year colleges, community colleges...                    NaN
# 38  c Includes those self-employed in an incorpora...                    NaN
# 39  d Self-employed or business owner in a noninco...                    NaN
# 40    e Includes employers not broken out separately.                    NaN
# 41  NOTES: Median annual salaries are for principa...                    NaN
# 42  SOURCE:  National Science Foundation, National...                    NaN
#
#    Unnamed: 2 4-year educational institutiona Unnamed: 4  \
# 31       3000                          100000       2500
# 32       1500                           91000       2000
# 33        NaN                             NaN        NaN
# 34        NaN                             NaN        NaN
# 35        NaN                             NaN        NaN
# 36        NaN                             NaN        NaN
# 37        NaN                             NaN        NaN
# 38        NaN                             NaN        NaN
# 39        NaN                             NaN        NaN
# 40        NaN                             NaN        NaN
# 41        NaN                             NaN        NaN
# 42        NaN                             NaN        NaN
#
#    Other educational institutionb Unnamed: 6 Private, for profitc Unnamed: 8  \
# 31                          70000      12500               134000       3000
# 32                          84000       5000               140000       8000
# 33                            NaN        NaN                  NaN        NaN
# 34                            NaN        NaN                  NaN        NaN
# 35                            NaN        NaN                  NaN        NaN
# 36                            NaN        NaN                  NaN        NaN
# 37                            NaN        NaN                  NaN        NaN
# 38                            NaN        NaN                  NaN        NaN
# 39                            NaN        NaN                  NaN        NaN
# 40                            NaN        NaN                  NaN        NaN
# 41                            NaN        NaN                  NaN        NaN
# 42                            NaN        NaN                  NaN        NaN
#
#    Private, nonprofit Unnamed: 10 Federal government Unnamed: 12  \
# 31             125000        5000             129000        5500
# 32             134000        8000             119000        4500
# 33                NaN         NaN                NaN         NaN
# 34                NaN         NaN                NaN         NaN
# 35                NaN         NaN                NaN         NaN
# 36                NaN         NaN                NaN         NaN
# 37                NaN         NaN                NaN         NaN
# 38                NaN         NaN                NaN         NaN
# 39                NaN         NaN                NaN         NaN
# 40                NaN         NaN                NaN         NaN
# 41                NaN         NaN                NaN         NaN
# 42                NaN         NaN                NaN         NaN
#
#    State or local government Unnamed: 14 Self-employedd Unnamed: 16 Othere  \
# 31                    112000        7500         115000       22000  99000
# 32                    108000        7500              S           S  96000
# 33                       NaN         NaN            NaN         NaN    NaN
# 34                       NaN         NaN            NaN         NaN    NaN
# 35                       NaN         NaN            NaN         NaN    NaN
# 36                       NaN         NaN            NaN         NaN    NaN
# 37                       NaN         NaN            NaN         NaN    NaN
# 38                       NaN         NaN            NaN         NaN    NaN
# 39                       NaN         NaN            NaN         NaN    NaN
# 40                       NaN         NaN            NaN         NaN    NaN
# 41                       NaN         NaN            NaN         NaN    NaN
# 42                       NaN         NaN            NaN         NaN    NaN
#
#    Unnamed: 18
# 31       19000
# 32        6500
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN

# %%
'''
Remove the last 10 rows with footnotes
and remove row 0 with subheadings
'''
sectorDF.drop(sectorDF.index[-10:], inplace = True)
sectorDF.drop(sectorDF.index[0], inplace = True)

# %%
'''
Remove the SE columns. I'm only interested in Median Salaries.
Row 0 shows that the "unnamed" columns are the "SE" columns
'''
sectorDF.drop(sectorDF.columns[sectorDF.columns.str.contains('Unnamed')], axis = 1, inplace = True)

# %%
#set the index to degree and clean footnotes from column headings
sectorDF.set_index('Field of study', inplace = True)
sectorDF.rename(columns={'4-year educational institutiona': '4-year educational institution', 'Other educational institutionb':'Other educational institution', 'Private, for profitc': 'Private, for profit', 'Self-employedd':'Self-employed', 'Othere':'Other'}, inplace = True)
sectorDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, All fields to Health
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   All full-time employed          32 non-null     object
#  1   4-year educational institution  32 non-null     object
#  2   Other educational institution   32 non-null     object
#  3   Private, for profit             32 non-null     object
#  4   Private, nonprofit              32 non-null     object
#  5   Federal government              32 non-null     object
#  6   State or local government       32 non-null     object
#  7   Self-employed                   32 non-null     object
#  8   Other                           32 non-null     object
# dtypes: object(9)
# memory usage: 2.5+ KB

# %%
sectorDF.head()
# Out:
#                                                    All full-time employed  \
# Field of study
# All fields                                                         110000
# Science                                                            104000
# Biological, agricultural, and environmental lif...                 100000
# Agricultural and food sciences                                     106000
# Biochemistry and biophysics                                        109000
#
#                                                    4-year educational institution  \
# Field of study
# All fields                                                                  90000
# Science                                                                     88000
# Biological, agricultural, and environmental lif...                          84000
# Agricultural and food sciences                                              94000
# Biochemistry and biophysics                                                 82000
#
#                                                    Other educational institution  \
# Field of study
# All fields                                                                 71000
# Science                                                                    71000
# Biological, agricultural, and environmental lif...                         69000
# Agricultural and food sciences                                             88000
# Biochemistry and biophysics                                                57000
#
#                                                    Private, for profit  \
# Field of study
# All fields                                                      137000
# Science                                                         135000
# Biological, agricultural, and environmental lif...              130000
# Agricultural and food sciences                                  125000
# Biochemistry and biophysics                                     129000
#
#                                                    Private, nonprofit  \
# Field of study
# All fields                                                     114000
# Science                                                        109000
# Biological, agricultural, and environmental lif...             105000
# Agricultural and food sciences                                 100000
# Biochemistry and biophysics                                    131000
#
#                                                    Federal government  \
# Field of study
# All fields                                                     120000
# Science                                                        118000
# Biological, agricultural, and environmental lif...             110000
# Agricultural and food sciences                                 115000
# Biochemistry and biophysics                                    114000
#
#                                                    State or local government  \
# Field of study
# All fields                                                             90000
# Science                                                                86000
# Biological, agricultural, and environmental lif...                     79000
# Agricultural and food sciences                                         79000
# Biochemistry and biophysics                                           108000
#
#                                                    Self-employed   Other
# Field of study
# All fields                                                 99000  124000
# Science                                                   100000  124000
# Biological, agricultural, and environmental lif...         99000   89000
# Agricultural and food sciences                             89000   65000
# Biochemistry and biophysics                                68000       D

# %% [markdown]
# Fourth sheet to import is Table 1-1. U.S. residing doctoral scientists and engineers, by fine field of doctorate and employment status: 2017
#
# Footnotes from Table 1-1
# Codes used in data tables: * = suppressed when population estimate < 25. D = suppressed to avoid disclosure of confidential information. na = not applicable. S = suppressed for reliability; coefficient of variation exceeds publication standards.
# SE = standard error.
# a Unemployed includes individuals who were not working during the survey reference week but had been seeking work in the prior 4 weeks or who were on layoff from their job.
# b Not employed or not seeking work includes individuals who were not working during the survey reference week and had not been seeking work in the prior 4 weeks because of family responsibilities, chronic illness, or other reasons.
# NOTES: Numbers are rounded to the nearest 50. Standard errors are rounded up to the nearest 25. Detail may not add to total because of rounding. Designation of full-time and part-time employment status is based on principal job only, not on all jobs held in labor force. For example, an individual could work part time in his or her principal job but full time in the labor force. Residence location is based on reported living location on 1 February 2017.
# SOURCE:  National Science Foundation, National Center for Science and Engineering Statistics, Survey of Doctorate Recipients: 2017.

# %%
numbersDF = pd.read_excel(r'..\data\raw\sdr2017_dst_1-1.xlsx', skiprows = 3)
numbersDF.head()
# Out:
#                                       Field of study   Total Unnamed: 2  \
# 0                                                NaN     NaN        NaN
# 1                                                NaN  Number         SE
# 2                                         All fields  967500       1225
# 3                                            Science  736700       1250
# 4  Biological, agricultural, and environmental li...  246850        725
#
#   Employed Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unemployeda  \
# 0    Total        NaN  Full time        NaN  Part time        NaN         NaN
# 1   Number         SE     Number         SE     Number         SE      Number
# 2   815100       1400     721950       1925      93150       1575       17100
# 3   612450       1500     533800       1875      78700       1425       12800
# 4   206900        925     188650       1100      18250        625        5150
#
#   Unnamed: 10 Retired Unnamed: 12 Not employed or not seeking workb  \
# 0         NaN     NaN         NaN                               NaN
# 1          SE  Number          SE                            Number
# 2         625  113450        1250                             21850
# 3         575   93550        1050                             17900
# 4         350   28100         750                              6700
#
#   Unnamed: 14
# 0         NaN
# 1          SE
# 2         750
# 3         700
# 4         400

# %%
numbersDF = numbersDF.transpose()
numbersDF.reset_index(inplace = True)
numbersDF = numbersDF.transpose()

# %%
numbersDF.iloc[2, 0] = 'dummy'
numbersDF.columns = numbersDF.iloc[2, :]

# %%
numbersDF.drop(numbersDF.columns[numbersDF.columns.str.contains('SE')], axis = 1, inplace = True)

# %%
numbersDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, index to 106
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dummy   106 non-null    object
#  1   Number  100 non-null    object
#  2   Number  101 non-null    object
#  3   Number  101 non-null    object
#  4   Number  101 non-null    object
#  5   Number  100 non-null    object
#  6   Number  100 non-null    object
#  7   Number  100 non-null    object
# dtypes: object(8)
# memory usage: 7.6+ KB

# %%
numbersDF.columns = numbersDF.iloc[0, :]

# %%
numbersDF.head()
# Out:
# index  Field of study   Total  Employed  Unnamed: 5  Unnamed: 7  Unemployeda  \
# index  Field of study   Total  Employed  Unnamed: 5  Unnamed: 7  Unemployeda
# 0                 NaN     NaN     Total   Full time   Part time          NaN
# 1               dummy  Number    Number      Number      Number       Number
# 2          All fields  967500    815100      721950       93150        17100
# 3             Science  736700    612450      533800       78700        12800
#
# index  Retired  Not employed or not seeking workb
# index  Retired  Not employed or not seeking workb
# 0          NaN                                NaN
# 1       Number                             Number
# 2       113450                              21850
# 3        93550                              17900

# %%
numbersDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, index to 106
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Field of study                     106 non-null    object
#  1   Total                              100 non-null    object
#  2   Employed                           101 non-null    object
#  3   Unnamed: 5                         101 non-null    object
#  4   Unnamed: 7                         101 non-null    object
#  5   Unemployeda                        100 non-null    object
#  6   Retired                            100 non-null    object
#  7   Not employed or not seeking workb  100 non-null    object
# dtypes: object(8)
# memory usage: 7.6+ KB

# %%
numbersDF.rename(columns={
    'Total': 'Graduates', 
    'Employed':'Total Employed', 
    'Unnamed: 5': 'Full Time', 
    'Unnamed: 7':'Part Time',
    'Unemployeda':'Unemployed',
    'Not employed or not seeking workb':'Not employed or not seeking work'}, inplace = True)
numbersDF.drop(numbersDF.index[0:3], inplace = True)
numbersDF.set_index('Field of study', inplace = True)

# %%
numbersDF.head()
# Out:
# index                                              Graduates Total Employed  \
# Field of study
# All fields                                            967500         815100
# Science                                               736700         612450
# Biological, agricultural, and environmental lif...    246850         206900
# Agricultural and food sciences                         20800          16350
# Agricultural sciences                                   1400           1000
#
# index                                              Full Time Part Time  \
# Field of study
# All fields                                            721950     93150
# Science                                               533800     78700
# Biological, agricultural, and environmental lif...    188650     18250
# Agricultural and food sciences                         15050      1300
# Agricultural sciences                                    800       200
#
# index                                              Unemployed Retired  \
# Field of study
# All fields                                              17100  113450
# Science                                                 12800   93550
# Biological, agricultural, and environmental lif...       5150   28100
# Agricultural and food sciences                            200    3700
# Agricultural sciences                                       *     400
#
# index                                              Not employed or not seeking work
# Field of study
# All fields                                                                    21850
# Science                                                                       17900
# Biological, agricultural, and environmental lif...                             6700
# Agricultural and food sciences                                                  500
# Agricultural sciences                                                             *

# %%
sectorDF.to_csv('../data/inProcess/sector.csv')
numbersDF.to_csv('../data/inProcess/numbers.csv')
